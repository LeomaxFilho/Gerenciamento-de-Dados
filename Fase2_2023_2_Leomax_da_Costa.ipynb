# %% [markdown]
# <a href="https://colab.research.google.com/github/LeomaxFilho/Gerenciamento-de-Dados/blob/main/Fase2_2023_2_Leomax_da_Costa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="TAIL"><img src="https://i.imgur.com/GRTE0OG.png" width="150" title="Tail Logo" /></a>
# # <font color ="#00b8ff">Processo seletivo TAIL 2023.2</font>

# %% [markdown]
# ## Introdução

# %% [markdown]
# Olá candidato! Para participar do processo seletivo, você deve abrir o link do colab abaixo e fazer uma cópia para seu drive e inserir as respostas nos campos.
#
# Após responder, basta compartilhar conosco e nos enviar o link no email: tail.ufpb@gmail.com com o assunto **PROCESSO SELETIVO 2023.2 - SEU_NOME**
#
# Para mais instruções, assista o vídeo de explicações e dúvidas que enviamos por email.
#
# Pedimos que envie o notebook até o dia 27/07/2023 às 23:59.
#
# Qualquer dúvida, lembre de nos contactar através do canal no [discord](https://discord.gg/XwNSVG3Q)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1OssbhPtXx9W7Vai5_WHCUa-F6VgeSYPc?usp=sharing)

# %% [markdown]
# ## Instruções:
# <br>1. Abra o Google Colaboratory;
# <br>2. Faça uma cópia no seu drive;
# <br>3. Localize o notebook e abra-o;
# <br>4. Responda o questionário;
# <br>5. Salve o notebook e submeta-o através de nosso email: tail.ufpb@gmail.com

# %% [markdown]
# ## Materiais

# %% [markdown]
# **Anexo :**
#
# Para auxilio com as questões, disponibilizamos o livro *Python para Estatísticos*, do professor Telmo de Menezes e Silva Filho, do Departamento de Estatística da Universidade Federal da Paraíba (UFPB):
#
# [**Python para Estatísticos**](https://tmfilho.github.io/pyestbook)
#
# Link para bibliotecas essênciais para desenvolver os problemas abaixo:
#
# [**Bibliotecas essenciais**](https://github.com/Manuelfjr/processo2fase_anexo)
#
# Slides das aulas de Thais:
#
# [**Slides**](https://sites.google.com/site/gaudenciothaisia/home/aulas)
#
# Outros materiais, específicos para resolução de certas questões, serão especificados em seus enunciados.

# %%
#@title Preencha os campos abaixo:

nome = 'Leomax da Costa Bandeira Filho' #@param {type:"string"}
email = 'leomax.filho@gmail.com' #@param {type:"string"}

# confira se os valores impressos correspondem ao que você digitou
print(nome)
print(email)
# Out:
# Leomax da Costa Bandeira Filho
# leomax.filho@gmail.com

# %% [markdown]
# ## Avisos
# Aqui vão uma série de avisos e dicas:
# * Se esforcem. Mesmo que não consigam responder tudo, deem o máximo de si.
# * Descrevam o que pensaram e como fizeram ou teriam feito para resolver a questão (isso é muito importante).
# * Se divirtam. Vai ser muito legal ter vocês conosco!
#
# ![](https://github.com/TailUFPB/processo2fase/raw/master/img/ygt.jpg)

# %% [markdown]
# # Questão 1: TAILUFPB

# %% [markdown]
# ## Descrição:

# %% [markdown]
# Para lidar com valores textuais, são utilizadas variáveis de tipo String, podendo ser tratados como Listas (outra Estrutura de Dados) em Python. Dessa forma, é possível identificar caracteres de um String a partir de seu índice, o que ajuda bastante em analisar o comportamento de uma certa palavra.

# %% [markdown]
# ## Tarefa:

# %% [markdown]
# Faça um programa que printe todos os números de 1 a 100, mas printe "TAIL" no lugar dos números divisíveis por 3, printe "UFPB" no lugar dos números divisíveis por 5, e printe "TAILUFPB" no lugar dos números divisíveis por 3 e por 5.

# %% [markdown]
# ## Exemplo:

# %% [markdown]
# 1
#
# 2
#
# TAIL
#
# 4
#
# UFPB
#
# TAIL
#
# 7
#
# ...
#
# 14
#
# TAILUFPB
#
# 16
#
# 17
#
# TAIL
#
# ...

# %% [markdown]
# ## Código:

# %%
# -*- coding: utf-8 -*-

def tailufpb(prompt):

  for number in prompt:

    if number % 3 == 0  and number % 5 == 0:
      print('TAILUFPB')
    elif number % 3 == 0:
      print('TAIL')
    elif number % 5 == 0:
      print('UFPB')
    else:
      print(number)

tailufpb(range(1,101))
# Out:
# 1
# 2
# TAIL
# 4
# UFPB
# TAIL
# 7
# 8
# TAIL
# UFPB
# 11
# TAIL
# 13
# 14
# TAILUFPB
# 16
# 17
# TAIL
# 19
# UFPB
# TAIL
# 22
# 23
# TAIL
# UFPB
# 26
# TAIL
# 28
# 29
# TAILUFPB
# 31
# 32
# TAIL
# 34
# UFPB
# TAIL
# 37
# 38
# TAIL
# UFPB
# 41
# TAIL
# 43
# 44
# TAILUFPB
# 46
# 47
# TAIL
# 49
# UFPB
# TAIL
# 52
# 53
# TAIL
# UFPB
# 56
# TAIL
# 58
# 59
# TAILUFPB
# 61
# 62
# TAIL
# 64
# UFPB
# TAIL
# 67
# 68
# TAIL
# UFPB
# 71
# TAIL
# 73
# 74
# TAILUFPB
# 76
# 77
# TAIL
# 79
# UFPB
# TAIL
# 82
# 83
# TAIL
# UFPB
# 86
# TAIL
# 88
# 89
# TAILUFPB
# 91
# 92
# TAIL
# 94
# UFPB
# TAIL
# 97
# 98
# TAIL
# UFPB

# %% [markdown]
# # Questão 2: K-ésimo maior elemento

# %% [markdown]
# ## Descrição:

# %% [markdown]
# A utilização de listas em qualquer linguagem de programação requer lógica por parte do desenvolvedor para implementação de suas funcionalidades. Uma informação importante a ser retida é qual o k-ésimo maior número dentro de uma lista, ou seja, descobrir qual número dentro de uma lista está na posição "k" em ordem do maior para o menor.

# %% [markdown]
# ## Tarefa:

# %% [markdown]
# Implemente um script em Python para descobrir o k-ésimo maior número dentro de uma lista de inteiros. Serão passados dois parâmetros para uma função: uma lista de inteiros e a posição "k".

# %% [markdown]
# ## Exemplos:

# %% [markdown]
# Ex.: Dados os seguintes parâmetros...
#
# inteiros = [1,2,3,4,5], k = 1, retorne 5 (5 é o 1º maior número)<br>
# inteiros = [5,2,1,4,10], k = 3, retorne 4 (4 é o 3º maior número)<br>
# inteiros = [200,100,20,50,7], k = 4, retorne 20 (20 é o 4º maior número)<br>

# %% [markdown]
# ## Questão:

# %%
# -*- coding: utf-8 -*-
import warnings

warnings.filterwarnings('ignore')


def kesimo_maior_numero(k):

  position = 1
  lista = [200,100,20,50,7]

  #aqui eu retiro os numeros que se repetem na lista
  for number in lista:
    list_n = [i for i, item in enumerate(lista) if item == number]
    if len(list_n) > 1:
      del lista[lista.index(number)]

  #não consegui com que o codigo rodasse sem que a lista estivesse em ordem crescente
  lista.sort()

  #caso o K seja maior que o tamanho da lista
  if k > len(lista):
    print('k maior que o numero de caracteres distintos da lista, digite outro K')
    return

  #analisa quais os numeros da lista comparando-os para conseguir reparar em qual o numero que corresponde a ordem pedida
  for number in lista:
    position = 1
    for posit in lista:
      if number > posit:
        position = position + 1
      if position == len(lista)-k+1:
        print('inteiros =',lista,' k =',k, 'retorne',number,'(',number,'e o',k,'º maior numero)')
        return


kesimo_maior_numero(4)
# Out:
# inteiros = [7, 20, 50, 100, 200]  k = 4 retorne 20 ( 20 e o 4 º maior numero)

# %% [markdown]
# # Questão 3: Análise de Dados
# ---

# %% [markdown]
# **Descrição:**
# \
# Nessa seção, você adentrará no âmbito da análise de dados, que se trata do processo de limpeza, inspeção, modelagem e transformação de dados, corroborando para uma melhor interpretação dos dados e tomadas de decisão mais incisivas. Após essa breve introdução, você terá de analisar o dataset [Suicide Rates](https://www.kaggle.com/datasets/russellyates88/suicide-rates-overview-1985-to-2016). O dataset é formado pelos seguintes dados:
#
# |                Coluna                | Descrição |
# |:------------------------------------:|:---------:|
# |                  Country                 |   País que aconteceu o suicídio       |
# |                  Year                |    Ano do suicído   |
# | Sex	| Sexo da pessoa |
# | Age	| Faixa etária da pessoa |
# | Suicides_no	| Número de suicídios ocorridos |
# | Population	| População do país |
# | Suicides/100k pop	| Taxa de suicídios por 100 mil habitantes |
# | Country-year |	Combinação de país e ano |
# | HDI for year | Índice de Desenvolvimento Humano (HDI) para o ano |
# | gdp_for_year | PIB do país no ano |
# | gdp_per_capita | PIB per capita do país |
# | Generation | Geração da pessoa |

# %% [markdown]
# ### 3.1 - Leitura dos dados e realização de descrição estatística
# ---

# %% [markdown]
# A seguir, o dataframe já estará montado pelo método `pd.read_csv()` da biblioteca `pandas`, a partir da execução da célula.
#
# Dica: Você pode acessar a documentação da biblioteca `pandas` [clicando aqui](https://pandas.pydata.org/docs/getting_started/index.html#getting-started). Após o processamento do dataframe, você terá de realizar uma descrição estatística dos dados.

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_csv('https://raw.githubusercontent.com/carlosfab/data_science/master/datasets/suicide_rates.csv',
                      sep = ','
                      )
#conseguimos observar que apenas a coluna hdi for year tem dados ausentes, portanto podemos retirar ou a coluna ou os casos incompletos
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  object
#  8   HDI for year        8364 non-null   float64
#  9    gdp_for_year ($)   27820 non-null  object
#  10  gdp_per_capita ($)  27820 non-null  int64
#  11  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %%
#aqui eu consigo observar os paises que estao listados no dataset podendo entao escolher o melhor deles (BRASIL)
dataset['age'].unique()
# Out:
# array(['15-24 years', '35-54 years', '75+ years', '25-34 years',
#        '55-74 years', '5-14 years'], dtype=object)

# %% [markdown]
# ### 3.2 - Limpeza dos dados
# ---

# %% [markdown]
# Após verificar o dataset acima e a relação das descrições com os valores existentes, realize o processo de limpeza dos dados, verificando possíveis inconsistências entre as instâncias (linhas que compõem o dataset). Mais uma vez, a leitura da documentação do `pandas` é uma excelente iniciativa.

# %% [markdown]
# _Sua resposta aqui_

# %%
# aqui observamos que na coluna HDI for year existem dados incompletos
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  object
#  8   HDI for year        8364 non-null   float64
#  9    gdp_for_year ($)   27820 non-null  object
#  10  gdp_per_capita ($)  27820 non-null  int64
#  11  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %%
# Inicialmente vamos retirar os dados que não constam HDI por ano, para termos uma tabela mais completa

dataset_hdi = dataset['HDI for year']

# Aqui retiramos do dataset os dados que não contem o hdi, para que dessa maneira permanecam apenas os dados que contem todas as informacoes

dataset_hdi = dataset[~dataset_hdi.isna()]

#tambem e de bom tom retirar a coluna coutry-year ja que ja temos esses dados separados em colunas diferentes
dataset_hdi = dataset_hdi.drop(['country-year'],axis =1)

dataset_hdi.sample(3)
# Out:
#              country  year     sex          age  suicides_no  population  \
# 26293        Ukraine  2005  female  15-24 years          139     3626595
# 27031  United States  2000    male  25-34 years         3938    20120529
# 17755    New Zealand  2010  female  35-54 years           51      635970
#
#        suicides/100k pop  HDI for year   gdp_for_year ($)   \
# 26293               3.83         0.713      86,142,018,069
# 27031              19.57         0.883  10,284,779,000,000
# 17755               8.02         0.905     146,583,831,538
#
#        gdp_per_capita ($)    generation
# 26293                1917    Millenials
# 27031               39218  Generation X
# 17755               36145  Generation X

# %%
#alem disso posso fazer a retirada dos outliars
#mas primeiramente eu tenho que capturar esses dados, farei para suicides_no

fig0, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(dataset_hdi['suicides_no'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a4a72021db0>,
#   <matplotlib.lines.Line2D at 0x7a4a720211b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7a4a72020df0>,
#   <matplotlib.lines.Line2D at 0x7a4a720219f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7a4a72022a10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a4a720222c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a4a72022140>],
#  'means': []}

# %%
q3, q1 = np.percentile(dataset_hdi['suicides_no'], [75, 25])

iqr = q3 - q1

lowpass_limit = q1 - (iqr * 1.5) #por nao haver suicidios menor que 0 nao e necessario o limite inferior

highpass_limit= q3 + (iqr * 1.5)

outliers = dataset_hdi['suicides_no'] < highpass_limit
outliers_real =  dataset_hdi['suicides_no'] < 2500
 # com uma analise mais profunda e possivel reparar que os numeros mais altos de suicidios estao presentes nas idades de 15-24 anos, sendo assim
#considerados quase sempre como outliers, mas na verdade so sao pontos reais na reta, entao sem base de calculo profunda eu vou retirar baseado no olhometro
dataset_hdi_outliers = dataset_hdi[outliers]
dataset_hdi_outliers_real = dataset_hdi[outliers_real]
dataset_hdi_outliers.head(3)
# Out:
#     country  year     sex          age  suicides_no  population  \
# 72  Albania  1995    male  25-34 years           13      232900
# 73  Albania  1995    male  55-74 years            9      178000
# 74  Albania  1995  female    75+ years            2       40800
#
#     suicides/100k pop  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# 72               5.58         0.619      2,424,499,009                 835
# 73               5.06         0.619      2,424,499,009                 835
# 74               4.90         0.619      2,424,499,009                 835
#
#          generation
# 72     Generation X
# 73           Silent
# 74  G.I. Generation

# %%
dataset_hdi_outliers_real.sample(3)
# Out:
#                             country  year     sex          age  suicides_no  \
# 8359                        Estonia  1995  female  55-74 years           53
# 21896  Saint Vincent and Grenadines  2013  female  15-24 years            0
# 19291                        Poland  2010  female    75+ years           94
#
#        population  suicides/100k pop  HDI for year  gdp_for_year ($)   \
# 8359       178879              29.63         0.719      4,373,665,146
# 21896        9748               0.00         0.717        721,207,148
# 19291     1637613               5.74         0.829    479,321,460,551
#
#        gdp_per_capita ($)  generation
# 8359                 3224      Silent
# 21896                7183  Millenials
# 19291               13304      Silent

# %%
fig01, ax1 = plt.subplots()
ax1.boxplot(dataset_hdi_outliers['suicides_no'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a4a738e9270>,
#   <matplotlib.lines.Line2D at 0x7a4a738eab90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7a4a738e9390>,
#   <matplotlib.lines.Line2D at 0x7a4a738e9f60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7a4a738e9030>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a4a738e9e70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a4a738e96f0>],
#  'means': []}

# %%
#agora ainda que o método do boxplot do matplot lib ainda perceba como outliers esses pontos, pelo método interquartil

# %% [markdown]
# ### 3.3 - Feature Engineering e Dados Categóricos
# ---

# %% [markdown]
# 3.3.1 - Em um problema de _Data Science_, é comum nos depararmos com um dataset cujos atributos não esclareçam com efetividade o comportamento de um dado fenômeno. Desta forma, cientistas de dados devem estar aptos a manipular atributos existentes e assim definir novos atributos, de acordo com os critérios estabelecidos. Este processo é descrito como _Feature Engineering_, e trata apenas da manipulação algébrica e/ou lógica de atributos (colunas, no contexto prático) com o intuito de alimentar o seu modelo de Machine Learning com dados relevantes à resolução do problema.
# Nesta etapa, você deverá utilizar sua intuição aliando criatividade para decidir como novos atributos podem ser definidos, a partir dos dados que você já possui.

# %% [markdown]
# Dica: Utilize as colunas existentes para gerar uma ou mais colunas com atributos distintos dos primeiros.

# %% [markdown]
# _Sua resposta aqui_

# %%
# para o uso dos dados no machine learning e necessario que esses dados sejam valores numericos para que dessa maneira seja possivel realizar o aprendizado
#portanto e de bom tom que mudemos o ranged das idades para numeros
#ps, atualmente sao lidos como object



dataset_hdi_outliers_age = dataset_hdi_outliers['age'].str.replace('years','')
dataset_hdi_outliers_age = dataset_hdi_outliers_age.str.replace(' ','')
dataset_hdi_outliers_age = dataset_hdi_outliers_age.str.replace('+','')
dataset_hdi_outliers_age = dataset_hdi_outliers_age.str.split('-', expand = True).astype(float)

dataset_hdi_outliers_age[['min_age','max_age']] = dataset_hdi_outliers_age
dataset_hdi_outliers_age = dataset_hdi_outliers_age[['min_age','max_age']]
dataset_hdi_outliers = pd.concat([dataset_hdi_outliers, dataset_hdi_outliers_age], axis=1)
dataset_hdi_outliers['media_age'] = (dataset_hdi_outliers_age['min_age'] + dataset_hdi_outliers_age['max_age'])/2
dataset_hdi_outliers['media_age'] = dataset_hdi_outliers['media_age'].fillna(75)



dataset_hdi_outliers.head(3)
# Out:
#     country  year     sex          age  suicides_no  population  \
# 72  Albania  1995    male  25-34 years           13      232900
# 73  Albania  1995    male  55-74 years            9      178000
# 74  Albania  1995  female    75+ years            2       40800
#
#     suicides/100k pop  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# 72               5.58         0.619      2,424,499,009                 835
# 73               5.06         0.619      2,424,499,009                 835
# 74               4.90         0.619      2,424,499,009                 835
#
#          generation  min_age  max_age  media_age
# 72     Generation X     25.0     34.0       29.5
# 73           Silent     55.0     74.0       64.5
# 74  G.I. Generation     75.0      NaN       75.0

# %% [markdown]
# 3.3.2 - Em poucos termos, algoritmos de Machine Learning só funcionam com valores numéricos. Isto significa que antes de treinar qualquer modelo, deve-se transformar os dados categóricos em dados numéricos. Encontre uma forma de *codificar* as colunas de dados categóricos, de forma que seu modelo consiga interpretar todos os atributos não-numéricos como numéricos.

# %% [markdown]
# _Sua resposta aqui_

# %%
# epossivel usar os numeros para representar os sexos das pessoas

dataset_hdi_outliers_sex = dataset_hdi_outliers.sex.map(lambda sex_number: '1' if sex_number in ['male']
                                                        else '0')
dataset_hdi_outliers['sex_number'] = dataset_hdi_outliers_sex
dataset_hdi_outliers.head(3)
# Out:
#     country  year     sex          age  suicides_no  population  \
# 72  Albania  1995    male  25-34 years           13      232900
# 73  Albania  1995    male  55-74 years            9      178000
# 74  Albania  1995  female    75+ years            2       40800
#
#     suicides/100k pop  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# 72               5.58         0.619      2,424,499,009                 835
# 73               5.06         0.619      2,424,499,009                 835
# 74               4.90         0.619      2,424,499,009                 835
#
#          generation  min_age  max_age  media_age sex_number
# 72     Generation X     25.0     34.0       29.5          1
# 73           Silent     55.0     74.0       64.5          1
# 74  G.I. Generation     75.0      NaN       75.0          0

# %% [markdown]
# ### 3.4 - Análise Exploratória dos Dados
# ---

# %% [markdown]
# Antes de qualquer análise mais aprofundada sobre um conjunto de dados, é necessário ter uma noção de como estes dados estão distribuídos, que valores são mais comuns entre os dados, o quão dispersos estão e se existem valores que se distinguem do dataset, de uma maneira geral. Todas estas informações são classificadas como estatísticas, e em ciência de dados é preciso ter ideias claras sobre a forma do conjunto de dados em questão, utilizando-se majoritariamente da visão como forma de comunicar e representar as estatísticas elementares destes dados. Realize uma análise exploratória sobre os dados deste problema, apresentando as medidas de localização, dispersão e os valores que não se repetem em cada coluna, utilizando a biblioteca `matplotlib.pyplot` para criar gráficos que representem estas medidas. Utilize boxplots para visualizar dados muito discrepantes entre as amostras do dataset.

# %% [markdown]
# _Sua resposta aqui_

# %%
#aqui eu consigo os países que aparecem na lista, consigo saber cada dado presente na coluna country
#dataset['country'].unique()

dataset_brasil = dataset.loc[dataset['country']=='Brazil']
dataset_brasil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372 entries, 4172 to 4543
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             372 non-null    object
#  1   year                372 non-null    int64
#  2   sex                 372 non-null    object
#  3   age                 372 non-null    object
#  4   suicides_no         372 non-null    int64
#  5   population          372 non-null    int64
#  6   suicides/100k pop   372 non-null    float64
#  7   country-year        372 non-null    object
#  8   HDI for year        120 non-null    float64
#  9    gdp_for_year ($)   372 non-null    object
#  10  gdp_per_capita ($)  372 non-null    int64
#  11  generation          372 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 37.8+ KB

# %%
#ao perceber que há ausencia de dados dentro dos dados listados no brazil eu faco outro data set so com os dados "tratados"
dataset_brasil_hdi = dataset_hdi.loc[dataset_hdi['country']=='Brazil']
dataset_brasil_hdi.info()

dataset_brasil_hdi_outliers = dataset_hdi_outliers_real.loc[dataset_hdi_outliers_real['country']=='Brazil']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 4172 to 4531
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             120 non-null    object
#  1   year                120 non-null    int64
#  2   sex                 120 non-null    object
#  3   age                 120 non-null    object
#  4   suicides_no         120 non-null    int64
#  5   population          120 non-null    int64
#  6   suicides/100k pop   120 non-null    float64
#  7   HDI for year        120 non-null    float64
#  8    gdp_for_year ($)   120 non-null    object
#  9   gdp_per_capita ($)  120 non-null    int64
#  10  generation          120 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 11.2+ KB

# %%
#Quais sao os anos que os dados foram analisados para o caso do Brasil
dataset_brasil_hdi['year'].unique()
# Out:
# array([1985, 1990, 1995, 2000, 2005, 2010, 2011, 2012, 2013, 2014])

# %%
df_2005 = dataset_brasil_hdi.loc[dataset_brasil_hdi['year']==2005]
df_2005 = df_2005[df_2005['age']=='15-24 years']
df_2005_male = df_2005[df_2005['sex']=='male']
df_2005_female = df_2005[df_2005['sex']=='female']
df_2005
# Out:
#      country  year     sex          age  suicides_no  population  \
# 4416  Brazil  2005    male  15-24 years         1247    18077858
# 4420  Brazil  2005  female  15-24 years          405    17659079
#
#       suicides/100k pop  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# 4416               6.90         0.702    891,630,175,813                5230
# 4420               2.29         0.702    891,630,175,813                5230
#
#       generation
# 4416  Millenials
# 4420  Millenials

# %%
df_1985 = dataset_brasil_hdi.loc[dataset_brasil_hdi['year']==1985]
df_1985 = df_1985[df_1985['age']=='15-24 years']
df_1985_male = df_1985[df_1985['sex']=='male']
df_1985_female = df_1985[df_1985['sex']=='female']
df_1985
# Out:
#      country  year     sex          age  suicides_no  population  \
# 4176  Brazil  1985    male  15-24 years          661    13834000
# 4181  Brazil  1985  female  15-24 years          280    13751800
#
#       suicides/100k pop  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# 4176               4.78         0.576    222,942,790,435                1898
# 4181               2.04         0.576    222,942,790,435                1898
#
#         generation
# 4176  Generation X
# 4181  Generation X

# %%
df_2014 = dataset_brasil_hdi.loc[dataset_brasil_hdi['year']==2014]
df_2014 = df_2014[df_2014['age']=='15-24 years']
df_2014_male = df_2014[df_2014['sex']=='male']
df_2014_female = df_2014[df_2014['sex']=='female']
df_2014
# Out:
#      country  year     sex          age  suicides_no  population  \
# 4524  Brazil  2014    male  15-24 years         1358    17606681
# 4529  Brazil  2014  female  15-24 years          371    17094729
#
#       suicides/100k pop  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# 4524               7.71         0.755  2,455,993,625,159               12975
# 4529               2.17         0.755  2,455,993,625,159               12975
#
#       generation
# 4524  Millenials
# 4529  Millenials

# %%
dataset_brasil_hdi = dataset_brasil_hdi[dataset_brasil_hdi['age']=='15-24 years']
dataset_brasil_hdi_male = dataset_brasil_hdi[dataset_brasil_hdi['sex']=='male']
dataset_brasil_hdi_female = dataset_brasil_hdi[dataset_brasil_hdi['sex']=='female']

# %%
#-----
#analise com relacao ao sexo no brasil

fig1, ax = plt.subplots()
ax.plot(dataset_brasil_hdi_male['year'],dataset_brasil_hdi_male['suicides_no'], label = "suicidos homens", marker = 'o', color='c')
ax.plot(dataset_brasil_hdi_female['year'],dataset_brasil_hdi_female['suicides_no'], label = "suicidos mulheres",marker = 'o', color='pink')

ax.set_title('Suicidios no Brasil')
ax.set_xlabel('Anos')
ax.set_ylabel('Numero de mortos')
fig1.legend()
fig1.show()

# %%
#relacao do pib com o numero de suicidiios

df_pib = dataset_hdi_outliers_real[dataset_hdi_outliers_real['age']=='15-24 years']
df_pib = df_pib.rename(columns={' gdp_for_year ($) ': 'gdp_for_year'})
df_pib_male = df_pib[df_pib['sex']=='male']
df_pib_female = df_pib[df_pib['sex']=='female']
df_pib.sample(5)
# Out:
#          country  year     sex          age  suicides_no  population  \
# 10628    Grenada  2010    male  15-24 years            0       11871
# 23045   Slovenia  1995  female  15-24 years            6      144100
# 22469  Singapore  1990  female  15-24 years           17      225500
# 1613   Australia  2000  female  15-24 years           78     1285283
# 3761     Belgium  2011  female  15-24 years           41      656675
#
#        suicides/100k pop  HDI for year     gdp_for_year  gdp_per_capita ($)  \
# 10628               0.00         0.737      771,015,889                8118
# 23045               4.16         0.782   21,273,055,398               11291
# 22469               7.54         0.718   36,152,027,893               14393
# 1613                6.07         0.898  415,034,227,218               23219
# 3761                6.24         0.886  527,008,453,887               50893
#
#          generation
# 10628    Millenials
# 23045  Generation X
# 22469  Generation X
# 1613   Generation X
# 3761     Millenials

# %%
fig2, ax = plt.subplots()

x_male = df_pib_male['gdp_for_year']
y_male = df_pib_male['suicides_no']
x_female = df_pib_female['gdp_for_year']
y_female = df_pib_female['suicides_no']

plt.plot(x_male,y_male, label = "suicidos homens", color='c')
plt.plot(x_female ,y_female, label = "suicidos mulheres", color='pink')

ax.set_title('Suicidioscom relacao ao pib')
ax.set_xlabel('PIB')
ax.set_ylabel('Numero de mortos')
fig2.legend()
fig2.show()

# %% [markdown]
# # Questão 4: Processamento de Linguagem Natural
# ---

# %% [markdown]
# **Descrição:**
# \
# Nessa seção você irá explorar a área da NLP, quem têm como objetivo obter informações de textos, e além disso, tratá-los afim de entender e imitar a conversa humana, criando novos textos a partir de uma base, por exemplo.

# %%
import pandas as pd
import numpy as np
import string

# %%
url = 'https://raw.githubusercontent.com/TailUFPB/processo2fase/master/2023.2/Datasets/Restaurant_Reviews.tsv'
df = pd.read_csv(url, sep='\t')
pd.set_option('display.max_colwidth', 200)

# %%
df.head(10)
# Out:
#                                                                                                             Review  \
# 0                                                                                         Wow... Loved this place.
# 1                                                                                               Crust is not good.
# 2                                                                        Not tasty and the texture was just nasty.
# 3                          Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.
# 4                                                      The selection on the menu was great and so were the prices.
# 5                                                                   Now I am getting angry and I want my damn pho.
# 6                                                                            Honeslty it didn't taste THAT fresh.)
# 7  The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.
# 8                                                                                        The fries were great too.
# 9                                                                                                   A great touch.
#
#    Liked
# 0      1
# 1      0
# 2      0
# 3      1
# 4      1
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1

# %% [markdown]
# ### 4.1 - Faça a Análise Exploratória do dataset criado, encontre:
# ---

# %% [markdown]
# 4.1.1 - Distribuição das classes (Labels = 0 ou 1)

# %% [markdown]
# _Sua resposta aqui_ (Plote gráficos para ajudar a mostrar seu raciocínio e os resultados achados)
#
# Exemplo: Diga se os dados estão balanceados e como você observou isso + outras observações rápidas dos dados que você está trabalhando.

# %%
# na verdade esta perfeitamente equilibrado
df.groupby('Liked').count()
# Out:
#        Review
# Liked
# 0         500
# 1         500

# %% [markdown]
# 4.1.2 - Palavras mais frequentes de cada classe (Faça uma contagem de palavras em cada classe e mostre as mais frequente em cada uma)

# %% [markdown]
# _Sua resposta aqui_

# %%
df_split = df['Review'].str.split(expand = True)
df_count = df_split.groupby(1).count()

# %%
df_count['Palavras_que_mais_se_repetem'] = df_count.sum(axis = 1)
df_count = df_count['Palavras_que_mais_se_repetem']

# %%
df_count = df_count.to_frame(name = 'Palavras_que_mais_se_repetem')
df_count = df_count.sort_values(['Palavras_que_mais_se_repetem'], ascending = False)

# %%
df_count.head(3)
# Out:
#      Palavras_que_mais_se_repetem
# 1
# was                           459
# is                            310
# I                             265

# %% [markdown]
# ### 4.2 - Faça a Limpeza de dados, apresente a sua forma escolhida para:
# ---

# %% [markdown]
# 4.2.1 - Remover pontuação e caracteres especiais, normalizar letras maiúsculas

# %% [markdown]
# _Sua resposta aqui_

# %%
df_dots = df['Review'].str.translate(str.maketrans('', '', string.punctuation))
df_dots.str.replace('...', '')
df_dots = pd.DataFrame(df_dots)

# %%
#parece que nao tem como tirar os ...
df_dots.head()
# Out:
#                                                                                    Review
# 0                                                                    Wow Loved this place
# 1                                                                       Crust is not good
# 2                                                Not tasty and the texture was just nasty
# 3  Stopped by during the late May bank holiday off Rick Steve recommendation and loved it
# 4                              The selection on the menu was great and so were the prices

# %% [markdown]
# 4.2.2 - Tokenizar palavras

# %% [markdown]
# Sua resposta aqui

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')

df_dots = pd.DataFrame(df_dots)
df_dots
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                                                                                                  Review
# 0                                                                                                                  Wow Loved this place
# 1                                                                                                                     Crust is not good
# 2                                                                                              Not tasty and the texture was just nasty
# 3                                                Stopped by during the late May bank holiday off Rick Steve recommendation and loved it
# 4                                                                            The selection on the menu was great and so were the prices
# ..                                                                                                                                  ...
# 995                                                                   I think food should have flavor and texture and both were lacking
# 996                                                                                                             Appetite instantly gone
# 997                                                                                   Overall I was not impressed and would not go back
# 998                                            The whole experience was underwhelming and I think well just go to Ninja Sushi next time
# 999  Then as if I hadnt wasted enough of my life there they poured salt in the wound by drawing out the time it took to bring the check
#
# [1000 rows x 1 columns]

# %%
df_dots['tokenized_sents'] = df_dots.apply(lambda row: nltk.word_tokenize(row['Review']), axis=1)
df_dots
# Out:
#                                                                                                                                  Review  \
# 0                                                                                                                  Wow Loved this place
# 1                                                                                                                     Crust is not good
# 2                                                                                              Not tasty and the texture was just nasty
# 3                                                Stopped by during the late May bank holiday off Rick Steve recommendation and loved it
# 4                                                                            The selection on the menu was great and so were the prices
# ..                                                                                                                                  ...
# 995                                                                   I think food should have flavor and texture and both were lacking
# 996                                                                                                             Appetite instantly gone
# 997                                                                                   Overall I was not impressed and would not go back
# 998                                            The whole experience was underwhelming and I think well just go to Ninja Sushi next time
# 999  Then as if I hadnt wasted enough of my life there they poured salt in the wound by drawing out the time it took to bring the check
#
#                                                                                                                                                      tokenized_sents
# 0                                                                                                                                          [Wow, Loved, this, place]
# 1                                                                                                                                             [Crust, is, not, good]
# 2                                                                                                                  [Not, tasty, and, the, texture, was, just, nasty]
# 3                                                             [Stopped, by, during, the, late, May, bank, holiday, off, Rick, Steve, recommendation, and, loved, it]
# 4                                                                                            [The, selection, on, the, menu, was, great, and, so, were, the, prices]
# ..                                                                                                                                                               ...
# 995                                                                                   [I, think, food, should, have, flavor, and, texture, and, both, were, lacking]
# 996                                                                                                                                      [Appetite, instantly, gone]
# 997                                                                                                     [Overall, I, was, not, impressed, and, would, not, go, back]
# 998                                                        [The, whole, experience, was, underwhelming, and, I, think, well, just, go, to, Ninja, Sushi, next, time]
# 999  [Then, as, if, I, hadnt, wasted, enough, of, my, life, there, they, poured, salt, in, the, wound, by, drawing, out, the, time, it, took, to, bring, the, check]
#
# [1000 rows x 2 columns]

# %% [markdown]
# 4.2.3 - Remover stop words

# %% [markdown]
# Sua resposta aqui

# %%
stop = stopwords.words('english')
stpwrd = r'\b(?:{})\b'.format('|'.join(stop))
df_dots['non_stopwords'] = df_dots['Review'].str.replace(stpwrd, '')

df_dots = pd.DataFrame(df_dots)
df_dots
# Out:
#                                                                                                                                  Review  \
# 0                                                                                                                  Wow Loved this place
# 1                                                                                                                     Crust is not good
# 2                                                                                              Not tasty and the texture was just nasty
# 3                                                Stopped by during the late May bank holiday off Rick Steve recommendation and loved it
# 4                                                                            The selection on the menu was great and so were the prices
# ..                                                                                                                                  ...
# 995                                                                   I think food should have flavor and texture and both were lacking
# 996                                                                                                             Appetite instantly gone
# 997                                                                                   Overall I was not impressed and would not go back
# 998                                            The whole experience was underwhelming and I think well just go to Ninja Sushi next time
# 999  Then as if I hadnt wasted enough of my life there they poured salt in the wound by drawing out the time it took to bring the check
#
#                                                                                                                                                      tokenized_sents  \
# 0                                                                                                                                          [Wow, Loved, this, place]
# 1                                                                                                                                             [Crust, is, not, good]
# 2                                                                                                                  [Not, tasty, and, the, texture, was, just, nasty]
# 3                                                             [Stopped, by, during, the, late, May, bank, holiday, off, Rick, Steve, recommendation, and, loved, it]
# 4                                                                                            [The, selection, on, the, menu, was, great, and, so, were, the, prices]
# ..                                                                                                                                                               ...
# 995                                                                                   [I, think, food, should, have, flavor, and, texture, and, both, were, lacking]
# 996                                                                                                                                      [Appetite, instantly, gone]
# 997                                                                                                     [Overall, I, was, not, impressed, and, would, not, go, back]
# 998                                                        [The, whole, experience, was, underwhelming, and, I, think, well, just, go, to, Ninja, Sushi, next, time]
# 999  [Then, as, if, I, hadnt, wasted, enough, of, my, life, there, they, poured, salt, in, the, wound, by, drawing, out, the, time, it, took, to, bring, the, check]
#
#                                                                                      non_stopwords
# 0                                                                                 Wow Loved  place
# 1                                                                                     Crust   good
# 2                                                                      Not tasty   texture   nasty
# 3                              Stopped    late May bank holiday  Rick Steve recommendation  loved
# 4                                                           The selection   menu  great     prices
# ..                                                                                             ...
# 995                                                      I think food   flavor  texture    lacking
# 996                                                                        Appetite instantly gone
# 997                                                          Overall I   impressed  would  go back
# 998                   The whole experience  underwhelming  I think well  go  Ninja Sushi next time
# 999  Then   I hadnt wasted enough   life   poured salt   wound  drawing   time  took  bring  check
#
# [1000 rows x 3 columns]

# %% [markdown]
# 4.2.4 - Stemming ou Lematização

# %% [markdown]
# _Sua resposta aqui_

# %%
from nltk.stem.snowball import SnowballStemmer

# Use English stemmer.
stemmizador = SnowballStemmer("english")

df_dots['stemming'] = df_dots['tokenized_sents'].apply(lambda x: [stemmizador.stem(y) for y in x]) # Stem every word.

# %%
df_dots
# Out:
#                                                                                                                                  Review  \
# 0                                                                                                                  Wow Loved this place
# 1                                                                                                                     Crust is not good
# 2                                                                                              Not tasty and the texture was just nasty
# 3                                                Stopped by during the late May bank holiday off Rick Steve recommendation and loved it
# 4                                                                            The selection on the menu was great and so were the prices
# ..                                                                                                                                  ...
# 995                                                                   I think food should have flavor and texture and both were lacking
# 996                                                                                                             Appetite instantly gone
# 997                                                                                   Overall I was not impressed and would not go back
# 998                                            The whole experience was underwhelming and I think well just go to Ninja Sushi next time
# 999  Then as if I hadnt wasted enough of my life there they poured salt in the wound by drawing out the time it took to bring the check
#
#                                                                                                                                                      tokenized_sents  \
# 0                                                                                                                                          [Wow, Loved, this, place]
# 1                                                                                                                                             [Crust, is, not, good]
# 2                                                                                                                  [Not, tasty, and, the, texture, was, just, nasty]
# 3                                                             [Stopped, by, during, the, late, May, bank, holiday, off, Rick, Steve, recommendation, and, loved, it]
# 4                                                                                            [The, selection, on, the, menu, was, great, and, so, were, the, prices]
# ..                                                                                                                                                               ...
# 995                                                                                   [I, think, food, should, have, flavor, and, texture, and, both, were, lacking]
# 996                                                                                                                                      [Appetite, instantly, gone]
# 997                                                                                                     [Overall, I, was, not, impressed, and, would, not, go, back]
# 998                                                        [The, whole, experience, was, underwhelming, and, I, think, well, just, go, to, Ninja, Sushi, next, time]
# 999  [Then, as, if, I, hadnt, wasted, enough, of, my, life, there, they, poured, salt, in, the, wound, by, drawing, out, the, time, it, took, to, bring, the, check]
#
#                                                                                      non_stopwords  \
# 0                                                                                 Wow Loved  place
# 1                                                                                     Crust   good
# 2                                                                      Not tasty   texture   nasty
# 3                              Stopped    late May bank holiday  Rick Steve recommendation  loved
# 4                                                           The selection   menu  great     prices
# ..                                                                                             ...
# 995                                                      I think food   flavor  texture    lacking
# 996                                                                        Appetite instantly gone
# 997                                                          Overall I   impressed  would  go back
# 998                   The whole experience  underwhelming  I think well  go  Ninja Sushi next time
# 999  Then   I hadnt wasted enough   life   poured salt   wound  drawing   time  took  bring  check
#
#                                                                                                                                                      stemming
# 0                                                                                                                                    [wow, love, this, place]
# 1                                                                                                                                      [crust, is, not, good]
# 2                                                                                                            [not, tasti, and, the, textur, was, just, nasti]
# 3                                                                 [stop, by, dure, the, late, may, bank, holiday, off, rick, steve, recommend, and, love, it]
# 4                                                                                         [the, select, on, the, menu, was, great, and, so, were, the, price]
# ..                                                                                                                                                        ...
# 995                                                                                [i, think, food, should, have, flavor, and, textur, and, both, were, lack]
# 996                                                                                                                                  [appetit, instant, gone]
# 997                                                                                                 [overal, i, was, not, impress, and, would, not, go, back]
# 998                                                        [the, whole, experi, was, underwhelm, and, i, think, well, just, go, to, ninja, sushi, next, time]
# 999  [then, as, if, i, hadnt, wast, enough, of, my, life, there, they, pour, salt, in, the, wound, by, draw, out, the, time, it, took, to, bring, the, check]
#
# [1000 rows x 4 columns]

# %% [markdown]
# 4.2.5 - Compare a Análise Exploratória antes e depois da limpeza e retirada de stop words

# %% [markdown]
# _Sua resposta aqui_

# %%
df_dots = df_dots['non_stopwords'].str.split(expand = True)
df_count_2 = df_dots.groupby(1).count()

df_count_2['Palavras_que_mais_se_repetem'] = df_count.sum(axis = 1)
df_count_2 = df_count_2['Palavras_que_mais_se_repetem']

df_count_2 = df_count_2.to_frame(name = 'Palavras_que_mais_se_repetem')
df_count_2 = df_count_2.sort_values(['Palavras_que_mais_se_repetem'], ascending = False)

df_count_2 = df_count_2.fillna(0)
df_count_2
# Out:
#          Palavras_que_mais_se_repetem
# 1
# I                               265.0
# place                           261.0
# food                            217.0
# service                         133.0
# staff                           123.0
# ...                               ...
# werent                            0.0
# wont                              0.0
# wouldnt                           0.0
# youre                             0.0
# zero                              0.0
#
# [534 rows x 1 columns]

# %% [markdown]
# ### 4.3 - Para trabalhar com Machine Learning, devemos transformar os dados textuais em numéricos, em NLP uma das técnicas pra isso é o Bag of Words(BoW):
# ---

# %% [markdown]
# 4.3.1 - Implemente o Bag of Words, os dados precisam ser representados numa matriz esparsa que conta a frequência das palavras.

# %% [markdown]
# _Sua resposta aqui_

# %%
# Seu código aqui

# %% [markdown]
# Com essa técnica é possível trabalhar com textos na Aprendizagem de Máquina, tem outras disponíveis, mas essa é uma das mais clássicas.
#
# Parabéns por chegar até aqui!

# %% [markdown]
# # Questão 5 - Visão Computacional
# ---

# %% [markdown]
# Dentro dessa atividade você terá contato com alguns exercícios de visão computacional, que nada mais é, do que gerir recursos a fim de ensinar uma máquina a "enxergar", fazer com que ela gere compreensão. De tal modo, os exercícios abaixo listados visam introduzir-te-á essa área da Inteligência artificial embasadas de forma direta a algumas práticas de visão.

# %% [markdown]
# ### 5.1 - Trabalhando com imagens
# ---
# Logo abaixo é possível ver descrito em código um processo de leitura e plotagem de imagem com python. Leve a figura abaixo em consideração para realizar todas as instruções das subseções da 4.1
#
# Obs: Em caso de abertura, ou reabertura de notebook, relembrar de sempre rodar as bibliotecas e varíaveis novamente

# %%
from PIL import Image
import cv2
import requests
import numpy as np

# %%
# Funções auxiliares

def convert_from_cv2_to_image(img: np.ndarray) -> Image:
    return Image.fromarray(img)


def convert_from_image_to_cv2(img: Image) -> np.ndarray:
    return np.asarray(img)


def img_from_url(url):
    img = Image.open(requests.get(url, stream=True).raw)
    return img

# %%
url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/40/Sunflower_sky_backdrop.jpg/280px-Sunflower_sky_backdrop.jpg'

pil_img = img_from_url(url)
pil_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=280x310>

# %% [markdown]
# ### 5.2 - Detecção de bordas
# ---

# %% [markdown]
# **Descrição:**
# Dentro da visão computacional existe o conceito de bordas, que nada mais é do que determinar características de contornos de objetos em uma foto.
#
# **Tarefa:**
# Tendo isso em mente, realize o processo de delimitação de bordas na imagem abaixo utilizando a função Canny Edge Detector do OpenCV.

# %%
'''
O código abaixo converte a imagem carregada pela biblioteca Pillow para o
formato do OpenCV (numpy array).
'''

open_cv_image = convert_from_image_to_cv2(pil_img)

# %%
# Seu código aqui
# Aplicar os filtros na variável 'open_cv_image' com as funções do OpenCV

# %%
'''
Depois de aplicar o filtro, converta de volta para o formato do Pillow
e printe a imagem.
'''

pillow_image = convert_from_cv2_to_image(open_cv_image)
pillow_image
# Out:
# <PIL.Image.Image image mode=RGB size=280x310>

# %% [markdown]
# ### 5.3 - Binarização
# ---

# %% [markdown]
# **Descrição:**
# O processo de binarização consiste em transformar os pixels de uma imagem em regiões pretas e brancas, resultando numa forma mais simplificada da image.
#
# **Tarefa:**
# Ralizar o processo de Binarização da imagem pelo OpenCV utilizando o método Otsu.

# %%
# Seu código aqui

# %% [markdown]
# ### 5.4 - Histograma
# ---

# %% [markdown]
# **Descrição:**
# Exibir uma imagem em histograma representa os tons distribuidos da imagem. Esse conceito é muito importante pois pode ser utilizado para equalizar a imagem através de um histograma.
#
# **Tarefa:**
# Transforme a imagem para escala de cinza e plote o histograma da imagem

# %%
# Seu código aqui

# %% [markdown]
# ### 5.5 - Mexendo com cores
# ---

# %% [markdown]
# **Descrição:** Para realizar manipulações em imagens, é essencial ter um conhecimento básico sobre filtros, faixas de cores, máscaras, e outros conceitos relacionados.
#
# **Tarefa:** Nesta atividade, você irá alterar a cor do girassol para uma tonalidade de sua preferência. Para isso, utilize um filtro para converter a imagem para o espaço de cores HSV. Em seguida, selecione a faixa de cores desejada e aplique uma máscara na imagem para realizar a transformação da cor escolhida no girassol.

# %%
# Seu código aqui

# %% [markdown]
# # **QUESTÃO EXTRA**
#
# ## Deixe a imaginação fluir
#
# Fazer parte da TAIL é uma oportuniade muito boa para agregar novos conhecimentos, conhecer novas pessoas e desenvolver skills. Porém, é muito importante que você também demonstre bastante criatividade e interesse. Por isso, nesta seção, a próxima questão que irá responder será a SUA questão. Isso mesmo, não leste errado. A próxima etapa deste notebook consiste com que você, participante do processo, crie e responda uma questão de sua própria autoria. Demonstre nela um reflexo de seu conhecimento atual na área de programação, inteligência artificial, ciência de dados, etc, tal qual, demonstrar a sua criatividade na elaboração de conceitos e perguntas. Lembrando sempre, esta etapa **NÃO É DE CARÁTER ELIMINATÓRIO**, dessa forma, não se preocupem se não quiser resolvê-la ou em desenvolver e destrinchar algo muito complexo, pode ser uma pergunta muito simples, mas que reflita seu atual nível de similaridade com os assuntos que a TAIL trabalha.

# %% [markdown]
# ### O PODER É DE VOCÊS!

# %% [markdown]
# [Utilize este campo para redigir e desenvolver a sua questão]

# %%
# Caso precise de código, utilize esta seção
